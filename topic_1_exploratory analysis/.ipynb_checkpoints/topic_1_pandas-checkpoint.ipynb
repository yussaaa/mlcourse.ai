# %%
import numpy as np
import pandas as pd
pd.set_option("display.precision", 2)

# %%
df = pd.read_csv('telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
df.Churn = df.Churn.astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
df.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3333.00            3333.00
# mean           101.06     437.18                   8.10             179.78
# std             39.82      42.37                  13.69              54.47
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# ...

# %%
df.describe(include=['object', 'bool'])
# Out:
#        State International plan Voice mail plan
# count   3333               3333            3333
# unique    51                  2               2
# top       WV                 No              No
# freq     106               3010            2411

# %%
df.Churn.value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df.Churn.value_counts(normalize=True)
# Out:
# 0    0.86
# 1    0.14
# Name: Churn, dtype: float64

# %%
df.sort_values(by='Total day minutes', ascending='True').tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 605     MO             112        415                 No              No
# 156     OH              83        415                 No              No
# 2594    OH             115        510                Yes              No
# 985     NY              64        415                Yes              No
# 365     CO             154        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 605                       0              335.5               77
# 156                       0              337.4              120
# 2594                      0              345.3               81
# 985                       0              346.8               55
# 365                       0              350.8               75
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sort_values(by=['Total day minutes', 'Total day calls'], ascending='True').tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 605     MO             112        415                 No              No
# 156     OH              83        415                 No              No
# 2594    OH             115        510                Yes              No
# 985     NY              64        415                Yes              No
# 365     CO             154        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 605                       0              335.5               77
# 156                       0              337.4              120
# 2594                      0              345.3               81
# 985                       0              346.8               55
# 365                       0              350.8               75
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.Churn.mean()
# Out:
# 0.14491449144914492

# %%
df[df.Churn==1].mean()
# Out:
# Account length            102.66
# Area code                 437.82
# Number vmail messages       5.12
# Total day minutes         206.91
# Total day calls           101.34
# Total day charge           35.18
# Total eve minutes         212.41
# Total eve calls           100.56
# Total eve charge           18.05
# Total night minutes       205.23
# Total night calls         100.40
# Total night charge          9.24
# Total intl minutes         10.70
# Total intl calls            4.16
# Total intl charge           2.89
# Customer service calls      2.23
# Churn                       1.00
# dtype: float64

# %%
df[(df['International plan'] == 'No')&(df['Voice mail plan']=='No')]['Total eve charge'].max()
# Out:
# 30.11

# %%
df.loc[2,'State':'Area code']
# Out:
# State              NJ
# Account length    137
# Area code         415
# Name: 2, dtype: object

# %%
df[-1:]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3332             39.85              265.9               82              22.6
#
#       Total night minutes  Total night calls  Total night charge  \
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3332                13.7                 4                3.7
#
#       Customer service calls  Churn
# 3332                       0      0

# %%
df.iloc[1:4,6:8]
# Out:
#    Total day minutes  Total day calls
# 1              161.6              123
# 2              243.4              114
# 3              299.4               71

# %%
df.max()
# Out:
# State                          WY
# Account length                243
# Area code                     510
# International plan            Yes
# Voice mail plan               Yes
# Number vmail messages          51
# Total day minutes         3.5e+02
# Total day calls               165
# Total day charge               60
# Total eve minutes         3.6e+02
# Total eve calls               170
# Total eve charge               31
# Total night minutes         4e+02
# Total night calls             175
# Total night charge             18
# Total intl minutes             20
# Total intl calls               20
# Total intl charge             5.4
# Customer service calls          9
# Churn                           1
# dtype: object

# %%
df.apply(np.max)
# Out:
# State                          WY
# Account length                243
# Area code                     510
# International plan            Yes
# Voice mail plan               Yes
# Number vmail messages          51
# Total day minutes         3.5e+02
# Total day calls               165
# Total day charge               60
# Total eve minutes         3.6e+02
# Total eve calls               170
# Total eve charge               31
# Total night minutes         4e+02
# Total night calls             175
# Total night charge             18
# Total intl minutes             20
# Total intl calls               20
# Total intl charge             5.4
# Customer service calls          9
# Churn                           1
# dtype: object

# %%
df[df['State'].apply(lambda s: s[0]=='O')].count()
# Lambda can't contain assignment
# Out:
# State                     217
# Account length            217
# Area code                 217
# International plan        217
# Voice mail plan           217
# Number vmail messages     217
# Total day minutes         217
# Total day calls           217
# Total day charge          217
# Total eve minutes         217
# Total eve calls           217
# Total eve charge          217
# Total night minutes       217
# Total night calls         217
# Total night charge        217
# Total intl minutes        217
# Total intl calls          217
# Total intl charge         217
# Customer service calls    217
# Churn                     217
# dtype: int64

# %%
d = {'No': False, 'Yes':True}
df['International plan'] = df['International plan'].map(d)
df.head()
# Out:
#   State  Account length  Area code  International plan Voice mail plan  \
# 0    KS             128        415               False             Yes
# 1    OH             107        415               False             Yes
# 2    NJ             137        415               False              No
# 3    OH              84        408                True              No
# 4    OK              75        415                True              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# df = df.replace({'Voice mail plan':d})
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# ### df.groupby(by=grouping_columns)[columns_to_show].function()

# %%
columns_to_show = ['Total day minutes', 'Total eve minutes', 
                   'Total night minutes']
df.groupby(['Churn'])[columns_to_show].describe(percentiles=[])
# Out:
#       Total day minutes                                   Total eve minutes  \
#                   count    mean    std  min    50%    max             count
# Churn
# 0                2850.0  175.18  50.18  0.0  177.2  315.6            2850.0
# 1                 483.0  206.91  69.00  0.0  217.6  350.8             483.0
#
#                                          Total night minutes                 \
#          mean    std   min    50%    max               count    mean    std
# Churn
# 0      199.04  50.29   0.0  199.6  361.8              2850.0  200.13  51.11
# 1      212.41  51.73  70.9  211.3  363.7               483.0  205.23  47.13
#
#
#         min     50%    max
# Churn
# 0      23.2  200.25  395.0
# 1      47.4  204.80  354.9

# %%
df.groupby(['Churn'])['Total day minutes'].describe(percentiles=[])
# Out:
#         count    mean    std  min    50%    max
# Churn
# 0      2850.0  175.18  50.18  0.0  177.2  315.6
# 1       483.0  206.91  69.00  0.0  217.6  350.8

# %%
df.groupby(['Churn'])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
#       Total day minutes                    Total eve minutes               \
#                    mean    std amin   amax              mean    std  amin
# Churn
# 0                175.18  50.18  0.0  315.6            199.04  50.29   0.0
# 1                206.91  69.00  0.0  350.8            212.41  51.73  70.9
#
#              Total night minutes
#         amax                mean    std  amin   amax
# Churn
# 0      361.8              200.13  51.11  23.2  395.0
# 1      363.7              205.23  47.13  47.4  354.9

# %% [markdown]
# ## Summary tables

# %%
pd.crosstab(df.Churn, df['International plan'])
# Out:
# International plan  False  True
# Churn
# 0                    2664    186
# 1                     346    137

# %%
pd.crosstab(df.Churn, df['International plan'], normalize=True)
# Out:
# International plan  False  True
# Churn
# 0                     0.8   0.06
# 1                     0.1   0.04

# %%
df.pivot_table(columns_to_show, ['Area code'], aggfunc='mean')
# Out:
#            Total day minutes  Total eve minutes  Total night minutes
# Area code
# 408                   177.18             201.28               199.21
# 415                   181.59             200.65               202.04
# 510                   178.79             201.32               200.23

# %%
# total_call = df['Total day calls'] + df['Total eve calls'] + \
#               df['Total night calls'] + df['Total intl calls']
# df.insert(len(df.columns),'Total_call', total_call)

df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
df['Total_Charge'] = df['Total day charge'] + df['Total eve charge'] + \
                     df['Total night charge'] + df['Total intl charge']
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn', 'Total_call', 'Total_Charge'],
#       dtype='object')

# %%
df = df.reindex(columns=['State','Area code', 'Account length', 'International plan',
       'Voice mail plan', 'Number vmail messages', 'Total day minutes',
       'Total day calls', 'Total day charge', 'Total eve minutes',
       'Total eve calls', 'Total eve charge', 'Total night minutes',
       'Total night calls', 'Total night charge', 'Total intl minutes',
       'Total intl calls', 'Total intl charge', 'Customer service calls',
       'Churn', 'Total_call', 'Total_Charge'])

# %%
df.head()
# Out:
#   State  Area code  Account length  International plan  Voice mail plan  \
# 0    KS        415             128               False             True
# 1    OH        415             107               False             True
# 2    NJ        415             137               False            False
# 3    OH        408              84                True            False
# 4    OK        415              75                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night minutes  \
# 0             45.07              197.4  ...                244.7
# ...

# %%
pd.crosstab(df.Churn, df['International plan'], margins=True)
# Out:
# International plan  False  True   All
# Churn
# 0                    2664   186  2850
# 1                     346   137   483
# All                  3010   323  3333

# %%
import matplotlib.pyplot as plt
# pip install seaborn 
import seaborn as sns
# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x='Churn', hue='International plan', data=df)

# %%
pd.crosstab(df.Churn, df['Customer service calls'], normalize=True)
# Out:
# Customer service calls     0     1     2     3     4         5         6  \
# Churn
# 0                       0.18  0.32  0.20  0.12  0.03  7.80e-03  2.40e-03
# 1                       0.03  0.04  0.03  0.01  0.02  1.20e-02  4.20e-03
#
# Customer service calls         7         8         9
# Churn
# 0                       1.20e-03  3.00e-04  0.00e+00
# 1                       1.50e-03  3.00e-04  6.00e-04

# %%
sns.countplot(x='Customer service calls', hue='Churn', data=df);

# %%
df['Many_service_calls'] = (df['Customer service calls'] > 3)

df.head()
# Out:
#   State  Area code  Account length  International plan  Voice mail plan  \
# 0    KS        415             128               False             True
# 1    OH        415             107               False             True
# 2    NJ        415             137               False            False
# 3    OH        408              84                True            False
# 4    OK        415              75                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night calls  \
# 0             45.07              197.4  ...                 91
# ...

# %%
pd.crosstab(df.Many_service_calls, df.Churn, margins=True)
# Out:
# Churn                  0    1   All
# Many_service_calls
# False               2721  345  3066
# True                 129  138   267
# All                 2850  483  3333

# %%
sns.countplot(x='Many_service_calls', hue='Churn',data=df)

# %%
pd.crosstab(df.Many_service_calls&df['International plan'], df.Churn)
# Out:
# Churn     0    1
# row_0
# False  2841  464
# True      9   19
